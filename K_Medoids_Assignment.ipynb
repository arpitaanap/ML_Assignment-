# %%
# !pip install scikit-learn-extra
# Out:
# Requirement already satisfied: scikit-learn-extra in c:\users\bhosa\anaconda32323\lib\site-packages (0.3.0)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\bhosa\anaconda32323\lib\site-packages (from scikit-learn-extra) (1.24.3)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\bhosa\anaconda32323\lib\site-packages (from scikit-learn-extra) (1.11.1)
# Requirement already satisfied: scikit-learn>=0.23.0 in c:\users\bhosa\anaconda32323\lib\site-packages (from scikit-learn-extra) (1.3.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\bhosa\anaconda32323\lib\site-packages (from scikit-learn>=0.23.0->scikit-learn-extra) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\bhosa\anaconda32323\lib\site-packages (from scikit-learn>=0.23.0->scikit-learn-extra) (2.2.0)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn_extra.cluster import KMedoids

url = "https://raw.githubusercontent.com/tanishq21/Mall-Customers/main/Mall_Customers.csv"
df = pd.read_csv(url)

X = df[['Annual Income (k$)', 'Spending Score (1-100)']].values

kmedoids = KMedoids(n_clusters=5, metric='manhattan', random_state=42)
kmedoids.fit(X)

plt.figure(figsize=(8, 6))
plt.scatter(X[:, 0], X[:, 1], c=kmedoids.labels_, cmap='rainbow', s=50)
plt.scatter(kmedoids.cluster_centers_[:, 0], kmedoids.cluster_centers_[:, 1],
            c='black', marker='X', s=200, label='Medoids')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.title('K-Medoids Clustering of Mall Customers')
plt.legend()
plt.grid(True)
plt.show()
